# %% [markdown]
# # Feature Extraction per batch of T sec

# %%
import pandas as pd
import csv

from analyzer_clean import Flow, _FLOW_FIELDS

# %% [markdown]
# ## Analyze each 10s batch
# - every 10 s a batch of flows is read
# - convert each batch into pandas df for feature extraction
#
# ### Definitions:
# - entry is each line in csv (packet from netflow)
# - conns is unique (src_ip, dst_ip)
# - flow is unique flow tuple (src_ip, src_port, dst_ip, dst_port, ip_protocol)
# - src_port is randomly assigned
# - change in distribution of dst_port may indicate port scanning
# - change in distribution of src_ip or dst_ip may indicate DoS

# %%
DATA = []
FLOW_LIST = []
T = 10

with open("data.csv", "r") as csvfile:
    # pass input data stream as open("data.csv", "r") to csv.reader for testing
    # read and process line by line don't read into list
    fin = csv.reader(csvfile)
    for e in fin:
        flow = Flow.from_csv(e)
        FLOW_LIST.append(flow)
        if int(flow.ts.strftime('%s')) % T == 0:
            DATA.append(FLOW_LIST)
            FLOW_LIST = []

# %% [markdown]
# ## Dataframe of features extracted
# - volumetric features per batch
#     - number of entries (packets)
#     - number of bytes (up/dw)
#     - number of ports and ips
#     - num packets per state (['closed', 'established', 'reset', 'new', 'closing', 'connecting'])
#
# - distribution features:
#     - count, mean, median, quartiles 25 and 75, 90 percentile
#     - group by (src_ip, dst_ip, dst_port, conn, flow)

# %%
from collections import defaultdict

def describe_distribution(num_param1_dist_by_param2):
    description = {}
    description["max"] = num_param1_dist_by_param2.max()
    description["mean"] = num_param1_dist_by_param2.mean()
    description["perc25"] = num_param1_dist_by_param2.quantile(.25)
    description["perc50"] = num_param1_dist_by_param2.median()
    description["perc75"] = num_param1_dist_by_param2.quantile(.75)
    description["perc90"] = num_param1_dist_by_param2.quantile(.9)
    return description

# %%
def get_volumetric_features(df, stats):
    stats['num_entries'] = len(df)
    
    # num => len(); count => unique.len()
    stats['count_dst_port'] = len( df['dst_port'].unique() )
    stats['count_src_port'] = len( df['src_port'].unique() )
    stats['count_dst_ip'] = len( df['dst_ip'].unique() )
    stats['count_src_ip'] = len( df['src_ip'].unique() )
    
    # number of packets (entries) in each state
    df_state_count = df.groupby('state')['dst_tx'].count()
    for state in ['closed', 'established', 'reset', 'new', 'closing', 'connecting']:
        if state in df_state_count:
            stats['num_state_'+state] = df_state_count[state]
    
    return stats

# %%
def get_distribution_features(df, stats, key):
    if key=='conn':
        pass
    elif key=='flow':
        pass
    elif key=='dst_ip':
        pass
    elif key=='src_ip':
        pass
    elif key=='dst_port':
        pass
    else:
        print("key??", key)
        
    return stats

# %%
# this computation is performed in batches every 10s
all_stats = defaultdict(list)
flow_batch = 0  ##counter for flow batch in DATA

for flow_list in DATA:
    df = pd.DataFrame(flow_list)
    stats = {}
    stats['flow_batch'] = flow_batch
    flow_batch += 1
    # VOLUMETRIC FEATURES ##stats = get_volumetric_features(df, stats)
    # (1) num entries
    stats['num_entries'] = len(df)
    # num => len(); count => unique.len()
    stats['count_dst_port'] = len( df['dst_port'].unique() )
    stats['count_src_port'] = len( df['src_port'].unique() )
    stats['count_dst_ip'] = len( df['dst_ip'].unique() )
    stats['count_src_ip'] = len( df['src_ip'].unique() )
    # number of packets (entries) in each state
    df_state_count = df.groupby('state')['dst_tx'].count()
    for state in ['closed', 'established', 'reset', 'new', 'closing', 'connecting']:
        if state in df_state_count:
            stats['num_state_'+state] = df_state_count[state]
        else:
            stats['num_state_'+state] = 0
    
    # DISTRIBUTION FEATURES
    # (2) by conn => unique (dst_ip, src_ip)
    ##stats = get_distribution_features(df, stats, 'conn')
    gp1 = df.groupby(['dst_ip', 'src_ip'])
    stats['count_conns'] = len(gp1)
    # dst port per conn
    _dist = gp1['dst_port'].count()
    for k,v in describe_distribution(_dist).items():
        stats['dst_port_per_conn_'+k] = v
        
    # (3) by flow => (dst_ip, dst_port, src_ip, src_port, protocol)
    ##stats = get_distribution_features(df, stats, 'flow')
    gp2 = df.groupby(['dst_ip', 'dst_port', 'src_ip', 'src_port', 'ip_protocol'])
    stats['count_flows'] = len(gp2)
    # mean flows per conn
    stats['num_flows_per_conn_mean'] = stats['count_flows']/stats['count_conns']    
    ## entries per flow
    #num_conns_per_flow_dist = gp2['bytes_up'].count()
    #num_flow_per_conn_dist = gp[['src_port', 'dst_port', 'ip_protocol']].count()
    # ...
    
    # (4) by dst_ip
    gp3 = df.groupby(['dst_ip'])
    # dst_port by dst_ip
    _dist = gp3['dst_port'].count()
    for k,v in describe_distribution(_dist).items():
        stats['dst_port_per_dst_ip_'+k] = v
    # src_ip by dst_ip
    _dist = gp3['src_ip'].count()
    for k,v in describe_distribution(_dist).items():
        stats['src_ip_per_dst_ip_'+k] = v
        
    # (5) by src_ip
    gp4 = df.groupby(['src_ip'])
    # dst_port by src_ip
    _dist = gp4['dst_port'].count()
    for k,v in describe_distribution(_dist).items():
        stats['dst_port_per_src_ip_'+k] = v
    # dst_ip by src_ip
    _dist = gp4['dst_ip'].count()
    for k,v in describe_distribution(_dist).items():
        stats['dst_ip_per_src_ip_'+k] = v
    
    # (6) by dst_port
    gp5 = df.groupby(['dst_port'])
    # dst_ip by dst_port
    _dist = gp5['dst_ip'].count()
    for k,v in describe_distribution(_dist).items():
        stats['dst_ip_per_dst_port_'+k] = v
    # src_ip by dst_port
    _dist = gp5['src_ip'].count()
    for k,v in describe_distribution(_dist).items():
        stats['src_ip_per_dst_port_'+k] = v
        
    # put in all_stats
    for k,v in stats.items():
        all_stats[k].append(v)

# %%
# check dataframe length
for k,v in all_stats.items():
    print( k, len(v) )

print(flow_batch, len(DATA))
# Out:
# flow_batch 12904
# num_entries 12904
# count_dst_port 12904
# count_src_port 12904
# count_dst_ip 12904
# count_src_ip 12904
# num_state_closed 12904
# num_state_established 12904
# num_state_reset 12904
# num_state_new 12904
# num_state_closing 12904
# num_state_connecting 12904
# count_conns 12904
# dst_port_per_conn_max 12904
# dst_port_per_conn_mean 12904
# dst_port_per_conn_perc25 12904
# dst_port_per_conn_perc50 12904
# dst_port_per_conn_perc75 12904
# dst_port_per_conn_perc90 12904
# count_flows 12904
# num_flows_per_conn_mean 12904
# dst_port_per_dst_ip_max 12904
# dst_port_per_dst_ip_mean 12904
# dst_port_per_dst_ip_perc25 12904
# dst_port_per_dst_ip_perc50 12904
# dst_port_per_dst_ip_perc75 12904
# dst_port_per_dst_ip_perc90 12904
# src_ip_per_dst_ip_max 12904
# src_ip_per_dst_ip_mean 12904
# src_ip_per_dst_ip_perc25 12904
# src_ip_per_dst_ip_perc50 12904
# src_ip_per_dst_ip_perc75 12904
# src_ip_per_dst_ip_perc90 12904
# dst_port_per_src_ip_max 12904
# dst_port_per_src_ip_mean 12904
# dst_port_per_src_ip_perc25 12904
# dst_port_per_src_ip_perc50 12904
# dst_port_per_src_ip_perc75 12904
# dst_port_per_src_ip_perc90 12904
# dst_ip_per_src_ip_max 12904
# dst_ip_per_src_ip_mean 12904
# dst_ip_per_src_ip_perc25 12904
# dst_ip_per_src_ip_perc50 12904
# dst_ip_per_src_ip_perc75 12904
# dst_ip_per_src_ip_perc90 12904
# dst_ip_per_dst_port_max 12904
# dst_ip_per_dst_port_mean 12904
# dst_ip_per_dst_port_perc25 12904
# dst_ip_per_dst_port_perc50 12904
# dst_ip_per_dst_port_perc75 12904
# dst_ip_per_dst_port_perc90 12904
# src_ip_per_dst_port_max 12904
# src_ip_per_dst_port_mean 12904
# src_ip_per_dst_port_perc25 12904
# src_ip_per_dst_port_perc50 12904
# src_ip_per_dst_port_perc75 12904
# src_ip_per_dst_port_perc90 12904
# 12904 12904

# %% [markdown]
# ### Plot stat vs flow_batch (time)

# %%
df_stats = pd.DataFrame( all_stats )

# %%
#df_stats.to_pickle("df_features_per_batch.pkl")

# %%
# Out:
#        flow_batch  num_entries  count_dst_port  count_src_port  count_dst_ip  \
# 0               0          484              41             458           112
# 1               1            1               1               1             1
# 2               2            1               1               1             1
# 3               3            1               1               1             1
# 4               4            1               1               1             1
# 5               5            1               1               1             1
# 6               6            1               1               1             1
# 7               7            1               1               1             1
# 8               8            1               1               1             1
# 9               9            1               1               1             1
# 10             10            1               1               1             1
# 11             11            1               1               1             1
# 12             12            1               1               1             1
# 13             13            1               1               1             1
# 14             14            1               1               1             1
# 15             15            1               1               1             1
# 16             16            1               1               1             1
# 17             17            1               1               1             1
# 18             18            1               1               1             1
# 19             19            1               1               1             1
# 20             20            1               1               1             1
# 21             21            1               1               1             1
# 22             22            1               1               1             1
# 23             23            1               1               1             1
# 24             24            1               1               1             1
# 25             25            1               1               1             1
# 26             26            1               1               1             1
# 27             27            1               1               1             1
# 28             28            1               1               1             1
# 29             29            1               1               1             1
# ...           ...          ...             ...             ...           ...
# 12874       12874            1               1               1             1
# 12875       12875            1               1               1             1
# 12876       12876            1               1               1             1
# 12877       12877            1               1               1             1
# 12878       12878            1               1               1             1
# 12879       12879            1               1               1             1
# 12880       12880            1               1               1             1
# 12881       12881            1               1               1             1
# 12882       12882            1               1               1             1
# 12883       12883            1               1               1             1
# 12884       12884          213              19             204            52
# 12885       12885            1               1               1             1
# 12886       12886            1               1               1             1
# 12887       12887            1               1               1             1
# 12888       12888            1               1               1             1
# 12889       12889            1               1               1             1
# 12884                        42.4
# 12885                         1.0
# 12886                         1.0
# 12887                         1.0
# 12888                         1.0
# 12889                         1.0
# 12890                         1.0
# 12891                         1.0
# 12892                         1.0
# 12893                         1.0
# 12894                         1.0
# 12895                         1.0
# 12896                         1.0
# 12897                         1.0
# 12898                         1.0
# 12899                         1.0
# 12900                         1.0
# 12901                         1.0
# 12902                         1.0
# 12903                         1.0
#
# [12904 rows x 57 columns]

# %% [markdown]
# ### Flow analysis
# - Are there more than 1 packets for the same flow? Distribution?
# - Number of flows that are closed (request and response)
# - States per flow distribution
# - distribution of volumes

# %%
# Number of entries per flow > 1
for flow_list in DATA:
    df = pd.DataFrame(flow_list)
    gp1 = df.groupby(['dst_ip','src_ip'])
    gp2 = df.groupby(['dst_ip', 'dst_port', 'src_ip', 'src_port', 'ip_protocol'])
    # conns per flow
    temp = gp2['src_tx'].count()
    temp2 = temp[temp>1]
    if len(temp2)>0:
        print(temp2)
# Out:
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.1.20        49718     tcp            2
# 10.12.87.1       8125      10.2.20.4        36659     udp            2
#                                             47465     udp            2
#                                             58772     udp            2
# 52.85.77.134     443       192.168.100.96   34140     tcp            2
# 74.201.65.31     443       10.2.1.39        60854     tcp            2
#                                             60855     tcp            2
#                                             60857     tcp            2
#                                             60858     tcp            2
# 91.189.89.22     443       192.168.100.237  33815     tcp            2
# 192.168.100.250  53        192.168.100.11   39145     udp            2
# 199.91.71.85     443       192.168.100.29   40388     tcp            2
# 199.91.71.89     443       10.2.38.2        41229     tcp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip          src_port  ip_protocol
# 10.12.0.31    80        10.2.20.4       59967     tcp            2
# 10.12.87.1    443       192.168.111.66  39280     tcp            2
#                                         39282     tcp            2
# 199.91.71.85  443       10.2.38.2       43065     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.2.17.1        443       192.168.111.226  48738     tcp            2
# 74.201.65.31     443       10.2.1.39        33001     tcp            2
#                                             33002     tcp            2
#                                             33003     tcp            2
# 192.168.100.250  53        192.168.100.11   59249     udp            2
# 199.91.71.85     123       192.168.100.106  123       udp            2
# 199.91.71.86     123       192.168.100.106  123       udp            2
#                  1194      192.168.100.106  50396     udp            2
# 199.91.71.89     443       10.2.38.2        44881     tcp            2
# 216.58.197.168   443       192.168.100.123  35985     tcp            2
# 224.0.0.251      5353      192.168.100.23   5353      udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 192.168.100.250  53        192.168.100.11   55726     udp            2
# 199.91.71.85     1194      192.168.100.24   52745     udp            2
# 199.91.71.86     1194      192.168.100.106  43093     udp            2
# 239.255.255.250  1900      192.168.100.96   36503     udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.1.20        49723     tcp            2
#                            10.2.20.1        60256     tcp            2
#                            10.2.20.7        48984     tcp            2
# 10.12.21.2       6801      10.2.20.8        40354     tcp            2
# 46.244.5.69      443       10.2.38.2        43580     tcp            2
# 192.168.100.250  53        192.168.100.11   34898     udp            2
# 199.91.71.86     1194      192.168.100.106  33173     udp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip           src_port  ip_protocol
# 10.12.87.1    2013      192.168.100.241  36019     tcp            2
#                         192.168.100.242  50243     tcp            2
# 74.201.65.30  443       10.2.1.39        59120     tcp            2
# 199.91.71.85  1194      192.168.100.24   38501     udp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10
.168.100.96  45989     tcp            2
#                                           45990     tcp            2
#                 8443      192.168.100.96  45989     tcp            2
#                 8888      192.168.100.96  45989     tcp            2
#                 9000      192.168.100.96  45990     tcp            2
#                 9001      192.168.100.96  45990     tcp            2
#                 9090      192.168.100.96  45990     tcp            2
#                 9100      192.168.100.96  45990     tcp            2
#                 9102      192.168.100.96  45989     tcp            2
#                 9999      192.168.100.96  45989     tcp            2
#                 10000     192.168.100.96  45991     tcp            2
#                 10001     192.168.100.96  45990     tcp            2
#                 10010     192.168.100.96  45991     tcp            2
#                 15000     192.168.100.96  45989     tcp            2
#                                           45990     tcp            2
#                 32768     192.168.100.96  45989     tcp            2
#                 32771     192.168.100.96  45990     tcp            2
# Name: src_tx, Length: 253, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  45376     tcp            2
#                                           45378     tcp            2
#                                           45380     tcp            2
#                                           45382     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.21.2      6800      10.2.20.8        54358     tcp            2
# 10.12.87.1      2013      192.168.100.240  42046     tcp            2
# 10.12.231.2     6801      10.2.20.8        37815     tcp            2
#                 6803      10.2.20.8        45428     tcp            2
# 10.12.231.3     6801      10.2.20.8        53453     tcp            2
# 192.168.100.96  80        192.168.100.96   45384     tcp            2
#                                            45386     tcp            2
#                                            45388     tcp            2
#                                            45390     tcp            2
#                                            45392     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  45394     tcp            2
#                                           45396     tcp            2
#                                           45398     tcp            2
#                                           45400     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  45402     tcp            2
#                                           45404     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  45406     tcp            2
#                                           45408     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  45410     tcp            2
#                                           45412     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  53        192.168.100.96  50601     tcp            2
#                                           50602     tcp            2
#                                           50603     tcp            2
#                                           50604     tcp            2
#                                           50605     tcp            2
#                 80        192.168.100.96  45414     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  689       tcp            2
#                                           45416     tcp            2
#                                           45418     tcp            2
#                                           45420     tcp            2
#                                           45422     tcp            2
#                                           45424     tcp            2
#                                           45426     tcp            2
#                                           45428     tcp            2
#                                           45430     tcp            2
#                                           45432     tcp            2
#                                           45434     tcp            2
#                                           45436     tcp            2
#                                           45438     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.96  80        192.168.100.96  45440     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.87.1       2013      192.168.100.244  47295     tcp            2
# 23.22.65.241     443       192.168.100.131  54160     tcp            2
# 107.178.243.85   443       192.168.100.145  51629     tcp            2
# 172.217.4.133    443       192.168.100.40   53381     udp            2
# 172.217.4.138    443       192.168.100.40   51031     udp            2
#                                             53470     tcp            2
#                                             53472     tcp            2
#                                             53476     tcp            2
# 173.194.203.188  5228      192.168.100.40   57568     tcp            2
# 192.168.100.96   80        192.168.100.96   45444     tcp            2
# 216.58.193.109   443       192.168.100.40   34086     udp            2
#                                             52398     tcp            2
#                                             52404     tcp            2
# 216.58.216.1     443       192.168.100.40   36794     udp            2
# 216.58.216.3     443       192.168.100.40   58385     udp            2
# 216.58.216.4     443       192.168.100.40   50497     udp            2
# 216.58.216.14    443       192.168.100.40   47179     udp            2
# 216.58.217.195   443       192.168.100.40   48829     udp            2
#                                             50168     tcp            2
# 216.58.217.202   443       192.168.100.40   53168     tcp            2
#                                             53170     tcp            2
# 216.58.217.206   443       192.168.100.40   33684     tcp            2
#                                             33686     tcp            2
#                                             33688     tcp            2
#                                             33694     tcp            2
#                                             33700     tcp            2
#                                             33702     tcp            2
#                                             33710     tcp            2
#                                             33712     tcp            2
#                                             33714     tcp            2
#                                             33728     tcp            2
#                                             48057     udp            2
#                                             48842     udp            2
#                                             52658     udp            2
# 216.58.219.8     443       192.168.100.40   44342     udp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100
cp            4
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.3        60197     tcp            2
#                            10.2.20.5        50791     tcp            2
#                            10.2.20.7        45915     tcp            2
# 10.12.87.1       443       10.2.1.39        40264     tcp            2
#                  8125      10.2.20.5        45419     udp            2
#                                             45799     udp            2
#                                             53548     udp            2
# 52.206.112.96    443       192.168.100.131  55462     tcp            2
# 54.244.95.160    443       192.168.100.131  55468     tcp            2
#                                             55486     tcp            2
# 54.245.235.1     443       192.168.100.131  55399     tcp            2
# 74.201.65.31     443       10.2.1.39        39152     tcp            2
#                                             39153     tcp            2
#                                             39154     tcp            2
# 136.147.40.227   443       192.168.100.188  35954     tcp            2
# 136.147.41.227   443       192.168.100.188  44462     tcp            2
# 192.168.100.250  53        192.168.100.11   36947     udp            2
# 192.168.100.255  137       192.168.100.136  137       udp            2
# 216.58.217.195   443       192.168.100.136  54176     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.1        60248     tcp            2
# 10.12.38.1       443       10.2.20.8        55637     tcp            2
#                                             55638     tcp            2
# 10.12.68.6       6800      10.2.20.8        55550     tcp            2
# 10.12.68.7       6800      10.2.20.8        60638     tcp            2
# 10.12.84.1       3306      10.2.20.8        32888     tcp            2
# 10.12.87.1       443       192.168.100.40   50228     tcp            2
#                  2013      192.168.100.244  47330     tcp            2
# 10.12.230.4      22        192.168.100.40   48132     tcp            2
# 10.12.231.2      6801      10.2.20.8        37774     tcp            2
# 46.244.5.69      443       10.2.1.38        35536     tcp            2
# 52.54.163.58     443       192.168.100.131  55496     tcp            2
# 192.168.100.188  42415     74.125.204.189   443       udp            2
# 192.168.100.198  80        192.168.100.96   725       tcp            4
# 199.91.71.85     443       10.2.38.2        53536     tcp            2
#                            192.168.100.78   42500     tcp            2
# 199.91.71.86     443       10.2.38.2        57856     tcp            2
# 199.91.71.89     443       192.168.100.93   44168     tcp            2
# 216.58.216.14    443       192.168.100.131  56189     udp            2
# 224.0.0.251      5353      192.168.100.237  5353      udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip          src_port  ip_protocol
# 10.12.40.1       3306      10.2.20.8       53311     tcp            2
# 10.12.42.1       3306      10.2.20.8       36535     tcp            2
#                                            36536     tcp            2
# 10.12.84.1       3306      10.2.20.8       36882     tcp            2
#                                            36894     tcp            2
# 74.201.65.31     443       10.2.1.39       39477     tcp            2
#                                            39484     tcp            2
#                                            39485     tcp            2
# 192.168.100.250  53        192.168.100.11  50580     udp            2
#                            192.168.100.30  36531     udp            2
# 199.91.71.89     443       192.168.100.12  49522     tcp            2
# 207.154.64.10    53        192.168.100.30  36531     udp            2
# Name: src_tx, dtype: int64
# dst_ip      dst_port  src_ip     src_port  ip_protocol
# 10.12.0.31  80        10.2.20.3  60202     tcp            2
# 10.12.41.1  3306      10.2.20.8  38792     tcp            2
# 10.12.87.1  443       10.2.1.39  40695     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.21       5672      10.2.254.49      48238     tcp            2
# 10.12.0.22       443       10.2.38.2        34629     tcp            2
# 10.12.0.31       80        10.2.1.20        49723     tcp            2
#                                             50310     tcp            2
#                            10.2.20.5        50525     tcp            2
#                            10.2.20.7        48993     tcp            2
#                                             49440     tcp            2
# 74.201.65.30     443       10.2.1.39        36944     tcp            2
# 104.192.136.114  443       10.2.1.39        41303     tcp            2
# 192.168.100.88   53        192.168.100.96   56886     tcp            4
#                  80        192.168.100.96   714       tcp            2
# 192.168.100.250  53        192.168.100.11   3769      udp            2
# 216.58.216.5     443       192.168.100.138  39932     tcp            2
# 216.58.217.197   443       192.168.100.131  60425     udp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip           src_port  ip_protocol
# 10.2.17.1     443       192.168.111.226  51324     tcp            2
# 10.12.0.22    443       192.168.111.202  55884     tcp            2
# 10.12.0.31    80        10.2.20.5        51066     tcp            2
#                                          51112     tcp            2
# 10.12.87.1    443       192.168.111.178  35066     tcp            2
#                                          35086     tcp            2
#                                          35088     tcp            2
#                                          35090     tcp            2
#                                          35092     tcp            2
#                                          35094     tcp            2
# 74.201.65.31  443       10.2.1.39        39810     tcp            2
# 199.91.71.89  443       10.2.38.2        45531     tcp            2
# 216.58.216.4  443       192.168.100.138  39214     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip          src_port  ip_protocol
# 10.12.0.21       5672      10.2.254.49     48238     tcp            2
# 10.12.0.31       80        10.2.1.20       50275     tcp            2
#                            10.2.20.6       40038     tcp            2
# 10.12.87.1       8125      10.2.20.6       37179     udp            2
#                                            52933     udp            2
#                                            55570     udp            2
# 104.192.136.114  443       10.2.1.39       41445     tcp            2
# 199.91.71.85     1194      192.168.100.24  50887     udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip          src_port  ip_protocol
# 192.168.100.139  53        192.168.100.96  46628     tcp            4
#                                            46631     tcp            4
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip     src_port  ip_protocol
# 10.12.0.31       80        10.2.20.6  39824     tcp            2
# 10.12.68.6       6800      10.2.20.8  55547     tcp            2
# 10.12.68.7       6801      10.2.20.8  38976     tcp            2
# 74.201.65.31     443       10.2.1.39  40000     tcp            2
# 104.192.136.114  443       10.2.20.8  58175     tcp            2
# 199.91.71.89     443       10.2.38.2  49124     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip     src_port  ip_protocol
# 10.12.0.31       80        10.2.20.4  59970     tcp            2
# 104.192.136.114  443       10.2.1.39  41628     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.1.20        49990     tcp            2
# 10.12.87.1       2013      192.168.100.241  36034     tcp            2
#                            192.168.100.242  50258     tcp            2
#                  8125      10.2.1.20        33176     udp            2
#                                             35040     udp            2
#                                             54980     udp            2
# 74.201.65.31     443       10.2.1.39        40138     tcp            2
# 192.168.100.250  53        192.168.100.11   22798     udp            2
# 199.91.71.85     443       10.2.38.2        49971     tcp            2
# 199.91.71.89     443       10.2.38.2        51780     tcp            2
#                  1194      192.168.100.24   41878     udp            2
# 255.255.255.255  68        192.168.100.254  67        udp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31    80        10.2.20.1        60682     tcp            2
#                         10.2.20.5        50515     tcp            2
# 10.12.21.2    6801      10.2.20.8        40411     tcp            2
# 10.12.68.7    6801      10.2.20.8        38932     tcp            2
# 10.12.87.1    443       192.168.111.66   40394     tcp            2
#               2013      192.168.100.244  47344     tcp            2
# 10.12.231.3   6800      10.2.20.8        52795     tcp            2
# 74.201.65.30  443       10.2.1.39        37408     tcp            2
# 199.91.71.89  443       192.168.100.70   57049     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.3        60198     tcp            2
#                            10.2.20.5        50514     tcp            2
#                                             50524     tcp            2
# 10.12.21.2       6800      10.2.20.8        54364     tcp            2
# 10.12.21.3       6800      10.2.20.8        53010     tcp            2
#                  6803      10.2.20.8        33319     tcp            2
# 10.12.68.6       6801      10.2.20.8        36452     tcp            2
# 10.12.68.7       6801      10.2.20.8        38976     tcp            2
# 10.12.87.1       443       192.168.111.178  35190     tcp            2
#                                             35192     tcp            2
#                                             35194     tcp            2
#                                             35196     tcp            2
#                                             35198     tcp            2
#                                             35200     tcp            2
# 10.12.231.2      6803      10.2.20.8        45402     tcp            2
# 10.22.10.1       3306      10.2.254.55      34125     tcp            2
# 10.22.11.1       3306      10.2.254.55      51421     tcp            2
# 52.33.9.222      443       192.168.100.173  38936     tcp            2
# 74.201.65.31     443       10.2.1.39        40388     tcp            2
#                                             40389     tcp            2
#                                             40390     tcp            2
#                                             40391     tcp            2
# 169.44.162.192   80        192.168.100.131  55630     tcp            2
# 192.168.66.250   137       192.168.66.254   1024      udp            2
# 192.168.100.250  53        192.168.100.11   47399     udp            2
# 199.91.71.89     443       10.2.38.2        51340     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.68.7      6800      10.2.20.8        60638     tcp            2
# 10.12.189.1     443       192.168.111.178  37720     tcp            2
# 10.12.231.3     6801      10.2.20.8        53283     tcp            2
# 46.244.5.69     443       10.2.1.38        43917     tcp            2
# 52.71.193.253   443       192.168.100.40   44776     tcp            2
# 54.148.39.0     80        192.168.100.131  55625     tcp            2
# 54.186.123.157  443       192.168.100.123  60648     tcp            2
# 74.201.65.30    443       10.2.1.39        37656     tcp            2
#                                            37657     tcp            2
#                                            37658     tcp            2
#                                            37659     tcp            2
#                                            37660     tcp            2
#                                            37661     tcp            2
#                                            37662     tcp            2
#                                            37663     tcp            2
#                                            37664     tcp            2
# 74.201.65.31    443       10.2.1.39        40437     tcp            2
# 198.35.26.96    443       192.168.100.131  55856     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.21       5672      10.2.254.49      48318     tcp            2
# 10.12.0.31       80        10.2.1.20        50143     tcp            2
#                            10.2.20.4        59971     tcp            2
# 74.125.28.189    443       192.168.100.116  36310     tcp            2
# 192.168.100.250  53        192.168.100.11   12209     udp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31      80        10.2.1.20        50181     tcp            2
#                           10.2.20.5        50520     tcp            2
# 10.12.87.1      443       192.168.111.178  35274     tcp            2
#                                            35276     tcp            2
#                                            35278     tcp            2
#                                            35280     tcp            2
#                                            35282     tcp            2
#                                            35284     tcp            2
#                 8125      10.2.1.20        43696     udp            2
#                                            55647     udp            2
#                                            57106     udp            2
# 54.230.138.165  443       192.168.100.131  55869     tcp            2
# 74.125.68.94    443       192.168.100.40   42708     udp            2
# 74.201.65.31    443       10.2.1.39        40563     tcp            2
#                                            40564     tcp            2
#                                            40565     tcp            2
# 216.58.199.1    443       192.168.100.40   35092     udp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 192.168.100.16  80        192.168.100.96  234       tcp            3
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.1.20        50275     tcp            2
#                            10.2.20.3        60196     tcp            2
#                                             60199     tcp            2
# 74.125.28.189    443       192.168.100.131  54225     tcp            2
# 74.201.65.30     443       10.2.1.39        37843     tcp            2
# 192.168.100.250  53        192.168.100.11   41358     udp            2
# 216.58.216.5     443       192.168.100.116  40054     tcp            2
# 239.255.255.250  1900      192.168.100.131  53806     udp            2
# Name: src_tx, dtype: int64
# dst_ip      dst_port  src_ip     src_port  ip_protocol
# 10.12.0.31  80        10.2.20.4  60474     tcp            2
# 10.12.68.7  6801      10.2.33.4  36928     tcp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip           src_port  ip_protocol
# 10.2.1.39     22        192.168.111.86   55188     tcp            2
#                                          55189     tcp            2
#               445       192.168.100.115  57705     tcp            2
#               29418     192.168.111.86   55187     tcp            2
# 10.12.0.31    80        10.2.1.20        49720     tcp            2
#                         10.2.20.4        59975     tcp            2
#                         10.2.20.6        39823     tcp            2
# 10.12.68.6    6801      10.2.20.8        36400     tcp            2
# 52.19.57.181  443       192.168.100.131  55919     tcp            2
# 199.91.71.89  443       10.2.38.2        51399     tcp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip     src_port  ip_protocol
# 74.201.65.31  443       10.2.1.39  40797     tcp            2
# 199.91.71.86  443       10.2.38.2  58045     tcp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10.2.1.38      443       192.168.111.106  49562     tcp            2
# 10.12.21.2     6800      10.2.20.8        54341     tcp            2
# 40.84.189.107  443       192.168.100.145  58679     tcp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10.1.254.121   443       192.168.100.188  60878     tcp            2
# 54.244.120.65  443       192.168.100.131  54264     tcp            2
#                                           54266     tcp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31     80        10.2.20.3        60195     tcp            2
# 10.22.11.1     3306      10.2.254.55      51421     tcp            2
# 52.85.77.60    443       192.168.100.16   59264     tcp            2
# 74.125.28.189  443       192.168.100.136  54309     tcp            2
# 74.201.65.31   443       10.2.1.39        40987     tcp            2
#                                           40990     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.4        59975     tcp            2
# 10.12.189.1      443       192.168.111.178  37876     tcp            2
#                                             37878     tcp            2
# 74.125.28.189    443       192.168.100.116  36310     tcp            2
# 192.168.100.250  53        192.168.100.11   22473     udp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip          src_port  ip_protocol
# 10.12.0.31      80        10.2.1.20       49718     tcp            2
#                           10.2.20.2       51404     tcp            2
# 74.201.65.31    443       10.2.1.39       41080     tcp            2
#                                           41081     tcp            2
# 192.168.100.93  161       10.2.1.39       35605     udp            2
# 199.91.71.85    443       192.168.100.77  45830     tcp            2
# 199.91.71.86    443       192.168.100.91  50786     tcp            2
# 199.91.71.89    443       192.168.100.7   44392     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.1        59713     tcp            2
#                                             60248     tcp            2
#                            10.2.20.2        51059     tcp            2
#                            10.2.20.4        59975     tcp            2
#                            10.2.20.7        49423     tcp            2
# 10.12.87.1       2013      192.168.100.240  42078     tcp            2
# 23.23.99.56      443       192.168.100.123  56424     tcp            2
# 192.168.100.250  53        192.168.100.11   31998     udp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31    80        10.2.1.20        50235     tcp            2
#                         10.2.20.1        60257     tcp            2
#                         10.2.20.4        59969     tcp            2
# 10.12.230.4   22        192.168.111.226  43118     tcp            2
# 74.201.65.30  443       10.2.1.39        38422     tcp            2
#                                          38423     tcp            2
#                                          38424     tcp            2
#                                          38429     tcp            2
# 199.91.71.85  1194      192.168.100.24   47130     udp            2
# 199.91.71.86  443       192.168.100.7    48518     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31      80        10.2.20.1        60258     tcp            2
#                           10.2.20.4        59975     tcp            2
#                                            60585     tcp            2
#                           10.2.20.5        50584     tcp            2
#                           10.2.20.6        40314     tcp            2
# 10.12.87.1      2013      192.168.100.243  53311     tcp            2
#                 8125      10.2.20.5        41475     udp            2
#                                            41861     udp            2
#                                            50162     udp            2
# 10.12.133.1     3306      10.2.254.55      49673     tcp            2
# 46.244.5.69     443       10.2.1.38        48606     tcp            2
# 74.201.65.30    443       10.2.1.39        38485     tcp            2
# 199.91.71.85    123       192.168.100.106  123       udp            2
# 199.91.71.86    123       192.168.100.106  123       udp            2
# 199.91.71.89    123       192.168.100.106  123       udp            2
#                 1194      192.168.100.106  51771     udp            2
# 216.58.217.206  443       192.168.100.116  56021     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31      80        10.2.20.4        60530     tcp            2
#                           192.168.100.240  32870     tcp            2
# 10.12.68.7      6801      10.2.20.8        38976     tcp            2
# 17.249.28.22    5223      192.168.100.131  61970     tcp            2
# 17.253.4.125    123       192.168.100.136  123       udp            2
# 136.147.42.227  443       192.168.100.188  59758     tcp            2
# 192.161.156.1   443       192.168.100.40   38284     tcp            2
#                                            38288     tcp            2
# 199.91.71.89    443       10.2.38.2        51780     tcp            2
# 216.58.217.206  443       192.168.100.131  64044     udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip          src_port  ip_protocol
# 10.2.1.39        22        192.168.100.96  44278     tcp            2
#                  8140      10.12.1.1       33519     tcp            2
#                                            38704     tcp            2
#                                            44422     tcp            2
#                                            46082     tcp            2
#                                            50737     tcp            2
#                                            54991     tcp            2
# 10.12.0.31       80        10.2.1.20       50290     tcp            2
# 10.12.87.1       443       192.168.111.66  40548     tcp            2
# 192.168.100.254  1194      98.207.16.69    64909     udp            2
# 199.91.71.86     443       10.2.38.2       38757     tcp            2
# 239.255.255.250  1900      192.168.100.10  47502     udp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10.2.254.56    3306      192.168.111.158  50099     tcp            2
# 10.12.0.21     5672      10.2.254.49      48318     tcp            2
# 10.12.0.31     80        10.2.20.1        60246     tcp            2
#                          10.2.20.4        59967     tcp            2
# 10.12.68.7     6801      10.2.20.8        38953     tcp            2
#                                           39012     tcp            2
# 10.12.87.1     2013      192.168.100.240  42079     tcp            2
# 10.12.231.2    6801      10.2.20.8        37715     tcp            2
# 52.44.248.176  443       192.168.100.131  56092     tcp            2
# 54.244.95.160  443       192.168.100.131  56107     tcp            2
# ...
# 199.91.71.89     1194      192.168.100.24  33485     udp            2
# 239.255.255.250  1900      192.168.100.40  56012     udp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip           src_port  ip_protocol
# 10.2.20.8     443       192.168.111.226  56886     tcp            2
# 10.12.0.31    80        10.2.20.6        40481     tcp            2
# 74.201.65.30  443       10.2.1.39        39999     tcp            2
# 172.217.5.72  443       192.168.100.131  57360     udp            2
# 199.91.71.86  1194      192.168.100.24   49354     udp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31     80        10.2.1.20        49877     tcp            2
#                          10.2.20.7        49471     tcp            2
# 10.12.189.1    443       192.168.111.178  38400     tcp            2
# 52.202.74.156  443       192.168.100.131  56414     tcp            2
# 54.214.47.71   443       192.168.100.131  56410     tcp            2
# 54.244.95.160  443       192.168.100.131  56387     tcp            2
# 74.201.65.30   443       10.2.1.39        40069     tcp            2
#                                           40070     tcp            2
# 199.91.71.86   1194      192.168.100.106  52872     udp            2
# 199.91.71.89   443       10.2.38.2        45951     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.22       443       10.2.38.2        34636     tcp            2
# 10.12.33.1       22        192.168.111.86   57532     tcp            2
# 10.12.68.6       6801      10.2.20.8        36483     tcp            2
# 10.12.231.3      6800      10.2.20.8        52876     tcp            2
#                  6801      10.2.20.8        53453     tcp            2
# 23.3.120.29      443       192.168.100.131  56436     tcp            2
# 31.13.70.36      443       192.168.100.131  56448     tcp            2
# 34.196.81.22     443       192.168.100.131  55961     tcp            2
# 35.163.3.77      443       192.168.100.131  56114     tcp            2
# 46.51.254.183    443       192.168.100.131  56447     tcp            2
# 50.97.40.233     443       192.168.100.131  56427     tcp            2
# 72.21.91.42      443       192.168.100.131  56433     tcp            2
# 74.125.200.154   443       192.168.100.131  56446     tcp            2
# 151.101.193.6    443       192.168.100.131  56423     tcp            2
# 169.54.129.27    443       192.168.100.131  56438     tcp            2
#                                             56439     tcp            2
# 192.168.100.250  53        192.168.100.11   13694     udp            2
# 199.91.71.85     443       10.2.38.2        50360     tcp            2
# 199.91.71.86     443       10.2.38.2        52788     tcp            2
# 239.255.255.250  1900      192.168.100.96   35920     udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.1.20        50003     tcp            2
#                            10.2.20.1        60904     tcp            2
#                            10.2.20.3        60854     tcp            2
# 74.201.65.31     443       10.2.1.39        43056     tcp            2
# 104.192.136.114  443       192.168.100.16   51075     tcp            2
# 199.91.71.85     443       10.2.38.2        50370     tcp            2
# 216.58.216.14    443       192.168.100.176  53054     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31      80        10.2.20.6        40482     tcp            2
# 104.196.229.58  443       192.168.111.158  51587     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.21       5672      10.2.254.49      48318     tcp            2
# 10.12.0.31       80        10.2.1.20        50407     tcp            2
#                            10.2.20.6        40483     tcp            2
# 10.12.87.1       443       192.168.100.40   50848     tcp            2
#                  2013      192.168.100.244  47399     tcp            2
# 192.168.100.250  53        192.168.100.11   17150     udp            2
# 199.91.71.86     443       192.168.100.30   52584     tcp            2
# 199.91.71.89     1194      192.168.100.24   54693     udp            2
# 216.58.217.197   443       192.168.100.120  32781     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31      80        10.2.20.7        49625     tcp            2
#                                            49669     tcp            2
# 10.12.68.7      6800      10.2.20.8        60638     tcp            2
#                 6801      10.2.20.8        39031     tcp            2
# 10.12.87.1      2013      192.168.100.240  42110     tcp            2
# 104.196.229.58  443       192.168.111.158  51805     tcp            2
# 199.91.71.86    443       10.2.38.2        39004     tcp            2
# 216.58.217.197  443       192.168.100.120  34710     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.2.17.1        22        192.168.111.226  45480     tcp            2
# 10.12.0.31       80        10.2.20.4        60616     tcp            2
# 10.12.21.2       6801      10.2.20.8        40354     tcp            2
#                                             40478     tcp            2
# 10.12.21.3       6803      10.2.20.8        33344     tcp            2
# 10.12.68.6       6800      10.2.20.8        55472     tcp            2
#                  6801      10.2.20.8        36483     tcp            2
# 10.12.68.7       6800      10.2.20.8        60508     tcp            2
#                  6801      10.2.20.8        39012     tcp            2
# 10.12.231.2      6801      10.2.20.8        37815     tcp            2
#                  6803      10.2.20.8        45428     tcp            2
# 10.12.231.3      6801      10.2.20.8        53427     tcp            2
# 104.192.136.114  443       192.168.111.158  51078     tcp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip          src_port  ip_protocol
# 10.12.0.21    5672      10.2.254.49     48318     tcp            2
# 10.12.0.31    80        10.2.1.20       50412     tcp            2
#                         10.2.20.7       48468     tcp            2
# 10.12.21.3    6803      10.2.20.8       33244     tcp            2
# 10.12.41.1    3306      10.2.20.8       38723     tcp            2
# 199.91.71.85  443       10.2.38.2       50438     tcp            2
# 199.91.71.89  1194      192.168.100.24  34185     udp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.4        60626     tcp            2
# 10.12.87.1       443       192.168.100.40   50828     tcp            2
#                                             50832     tcp            2
#                                             50844     tcp            2
#                                             50848     tcp            2
#                                             50852     tcp            2
#                                             50866     tcp            2
#                            192.168.111.66   40656     tcp            2
#                                             40658     tcp            2
#                                             40720     tcp            2
#                                             40730     tcp            2
# 74.201.65.31     443       10.2.1.39        43647     tcp            2
# 104.196.229.58   443       192.168.111.158  52029     tcp            2
# 192.168.100.250  53        192.168.100.11   55876     udp            2
# 199.91.71.86     443       10.2.38.2        57760     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.4        60619     tcp            2
#                            10.2.20.6        40482     tcp            2
# 74.201.65.30     443       10.2.1.39        40955     tcp            2
#                                             40956     tcp            2
#                                             40958     tcp            2
# 136.147.41.226   443       192.168.100.188  36874     tcp            2
# 192.168.100.250  53        192.168.100.11   7679      udp            2
# 199.91.71.85     1194      192.168.100.106  46697     udp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.12.0.21      5672      10.2.254.49      48318     tcp            2
# 10.12.0.31      80        10.2.1.20        50410     tcp            2
#                           10.2.20.4        60618     tcp            2
#                           10.2.20.5        51044     tcp            2
#                           10.2.20.6        40481     tcp            2
# 10.12.41.1      3306      10.2.20.8        38832     tcp            2
# 10.12.87.1      8125      10.2.20.5        48476     udp            2
#                                            51906     udp            2
#                                            58480     udp            2
# 10.12.231.3     6801      10.2.20.8        53404     tcp            2
# 64.233.188.188  5228      192.168.100.123  34106     tcp            2
# 199.91.71.85    443       192.168.100.93   44632     tcp            2
#                           192.168.100.239  58136     tcp            2
# 199.91.71.89    443       192.168.100.70   58165     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.2.1.39        22        192.168.111.86   55526     tcp            2
#                                             55527     tcp            2
# 10.2.20.8        443       192.168.111.226  57072     tcp            2
# 104.192.136.114  443       10.2.1.39        45504     tcp            2
# 199.91.71.86     443       10.2.38.2        57967     tcp            2
#                                             57971     tcp            2
# Name: src_tx, dtype: int64
# dst_ip         dst_port  src_ip           src_port  ip_protocol
# 10.2.1.39      22        192.168.111.86   55549     tcp            2
#                                           55551     tcp            2
# 10.12.21.2     6800      10.2.20.8        54364     tcp            2
# 10.12.21.3     6800      10.2.20.8        52976     tcp            2
#                                           53010     tcp            2
# 10.12.40.1     3306      10.2.20.8        53317     tcp            2
# 10.12.68.6     6801      10.2.20.8        36414     tcp            2
# 10.12.68.7     6800      10.2.20.8        60556     tcp            2
#                6801      10.2.20.8        38947     tcp            2
# 10.12.84.1     3306      10.2.20.8        36888     tcp            2
# 10.12.231.2    6801      10.2.20.8        37802     tcp            2
# 10.12.231.3    6800      10.2.20.8        52755     tcp            2
#                                           52842     tcp            2
#                6801      10.2.20.8        53404     tcp            2
# 54.244.120.65  443       192.168.100.131  56563     tcp            2
# 74.201.65.30   443       10.2.1.39        41305     tcp            2
# 199.91.71.89   443       10.2.38.2        51780     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.2.17.1        443       192.168.111.226  52318     tcp            2
# 10.12.21.2       6801      10.2.20.8        40364     tcp            2
# 10.12.68.6       6800      10.2.20.8        55578     tcp            2
#                  6801      10.2.20.8        36452     tcp            2
# 10.12.68.7       6801      10.2.20.8        38976     tcp            2
# 10.12.231.2      6803      10.2.20.8        45402     tcp            2
# 10.12.231.3      6801      10.2.20.8        53393     tcp            2
#                                             53427     tcp            2
# 104.192.136.114  443       192.168.111.158  52297     tcp            2
# 192.168.100.250  53        192.168.100.11   50249     udp            2
# 199.91.71.89     1194      192.168.100.106  36367     udp            2
# 207.154.68.50    30233     192.168.100.183  2235      udp            2
# 216.58.216.14    443       192.168.100.40   44876     udp            2
# Name: src_tx, dtype: int64
# dst_ip        dst_port  src_ip     src_port  ip_protocol
# 10.12.0.31    80        10.2.1.20  50003     tcp            2
#                         10.2.20.2  51271     tcp            2
#                         10.2.20.4  60057     tcp            2
#                         10.2.20.5  51156     tcp            2
# 10.12.87.1    8125      10.2.1.20  39702     udp            2
#                                    39734     udp            2
#                                    45326     udp            2
#                         10.2.20.2  33793     udp            2
#                                    33794     udp            2
#                                    47350     udp            2
#                         10.2.20.4  40967     udp            2
#                                    45921     udp            2
#                                    54436     udp            2
# 74.201.65.31  443       10.2.1.39  44367     tcp            2
#                                    44368     tcp            2
#                                    44369     tcp            2
#                                    44370     tcp            2
# Name: src_tx, dtype: int64
# dst_ip          dst_port  src_ip           src_port  ip_protocol
# 10.2.33.4       443       192.168.111.46   57786     tcp            2
# 10.12.0.31      80        10.2.20.7        49611     tcp            2
# 10.12.230.4     22        192.168.100.40   48132     tcp            2
# 64.233.189.139  443       192.168.100.15   34470     tcp            2
# 74.201.65.30    443       10.2.1.39        41789     tcp            2
#                                            41794     tcp            2
# 199.91.71.89    443       10.2.38.2        46150     tcp            2
# 216.58.216.5    443       192.168.100.40   56775     udp            2
# 216.58.216.14   443       192.168.100.176  53054     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.20.2        51703     tcp            2
#                            10.2.20.3        60864     tcp            2
#                            10.2.20.5        51158     tcp            2
# 54.192.87.45     443       192.168.100.116  45072     tcp            2
# 192.168.100.250  53        192.168.100.11   4072      udp            2
# 199.91.71.86     443       10.2.38.2        39149     tcp            2
# 239.255.255.250  1900      10.1.20.11       2438      udp            2
#                            192.168.100.40   51832     udp            2
# Name: src_tx, dtype: int64
# dst_ip      dst_port  src_ip     src_port  ip_protocol
# 10.12.0.31  80        10.2.20.4  60307     tcp            2
#                                  60618     tcp            2
# Name: src_tx, dtype: int64
# dst_ip           dst_port  src_ip           src_port  ip_protocol
# 10.12.0.31       80        10.2.1.20        49135     tcp            2
#                            10.2.20.3        60861     tcp            2
#                            10.2.20.5        49915     tcp            2
#                                             51156     tcp            2
# 10.12.87.1       8125      10.2.20.5        39453     udp            2
#                                             56794     udp            2
#                                             59177     udp            2
# 52.8.76.33       443       192.168.100.188  60264     tcp            2
# 173.194.202.188  5228      192.168.100.96   37062     tcp            2
# 199.91.71.89     443       192.168.100.98   48101     tcp            2
# 239.255.255.250  1900      192.168.100.96   47547     udp            2
# Name: src_tx, dtype: int64
